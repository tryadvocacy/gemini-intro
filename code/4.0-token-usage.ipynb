# %%
from google import genai
import os

import os
import getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"var: ")

_set_env("GEMINI_API_KEY")

client = genai.Client()
prompt = "The quick brown fox jumps over the lazy dog."

# Count tokens using the new client method.
total_tokens = client.models.count_tokens(
    model="gemini-2.5-flash", contents=prompt
)
print("total_tokens: ", total_tokens)
# ( e.g., total_tokens: 10 )

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt
)

# The usage_metadata provides detailed token counts.
print(response.usage_metadata)
# ( e.g., prompt_token_count: 11, candidates_token_count: 73, total_token_count: 84 )
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> prompt = "The quick brown fox jumps over the lazy dog."
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> # Count tokens using the new client method.
# ---> <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> total_tokens = client.models.count_tokens(
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>     model="gemini-2.5-flash", contents=prompt
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> )
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> print("total_tokens: ", total_tokens)
#      <a href='vscode-notebook-cell:/Users/greatmaster/Desktop/projects/oreilly-live-trainings/gemini-intro/notebooks/6.0-token-usage.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> # ( e.g., total_tokens: 10 )
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/google/genai/models.py:4737, in Models.count_tokens(self, model, contents, config)
#    4734 request_dict = _common.convert_to_dict(request_dict)
#    4735 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4737 response = self._api_client.request(
#    4738     'post', path, request_dict, http_options
#    4739 )
#    4741 response_dict = {} if not response.body else json.loads(response.body)
#    4743 if self._api_client.vertexai:
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/google/genai/_api_client.py:1314, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1304 def request(
#    1305     self,
#    1306     http_method: str,
#    (...)
#    1309     http_options: Optional[HttpOptionsOrDict] = None,
#    1310 ) -> SdkHttpResponse:
#    1311   http_request = self._build_request(
#    1312       http_method, path, request_dict, http_options
#    1313   )
# -> 1314   response = self._request(http_request, http_options, stream=False)
#    1315   response_body = (
#    1316       response.response_stream[0] if response.response_stream else ''
#    1317   )
#    1318   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/google/genai/_api_client.py:1150, in BaseApiClient._request(self, http_request, http_options, stream)
#    1147     retry = tenacity.Retrying(**retry_kwargs)
#    1148     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1150 return self._retry(self._request_once, http_request, stream)
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/google/genai/_api_client.py:1127, in BaseApiClient._request_once(self, http_request, stream)
#    1119 else:
#    1120   response = self._httpx_client.request(
#    1121       method=http_request.method,
#    1122       url=http_request.url,
#    (...)
#    1125       timeout=http_request.timeout,
#    1126   )
# -> 1127   errors.APIError.raise_for_response(response)
#    1128   return HttpResponse(
#    1129       response.headers, response if stream else [response.text]
#    1130   )
#
# File ~/miniconda3/envs/oreilly-gemini/lib/python3.10/site-packages/google/genai/errors.py:108, in APIError.raise_for_response(cls, response)
#     106 status_code = response.status_code
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#     110   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
