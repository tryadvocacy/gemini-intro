# %% [markdown]
# # Gemini App Chatting with PDFs

# %%
import os
import getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"var: ")

_set_env("GEMINI_API_KEY")

# %%
# !wget https://arxiv.org/pdf/2308.03688 && mv 2308.03688 ./assets-resources/paper.pdf
# Out:
# --2025-05-01 12:23:59--  https://arxiv.org/pdf/2308.03688
# Resolving arxiv.org (arxiv.org)... 151.101.195.42, 151.101.3.42, 151.101.67.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.195.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23176585 (22M) [application/pdf]
# Saving to: ‘2308.03688’
#
# 2308.03688          100%[===================>]  22.10M   105MB/s    in 0.2s
#
# 2025-05-01 12:23:59 (105 MB/s) - ‘2308.03688’ saved [23176585/23176585]

# %%
from google import genai
from google.genai import types
import httpx
import os

gemini_api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=gemini_api_key)

doc_url = "https://arxiv.org/pdf/2308.03688"

# Retrieve and encode the PDF byte
doc_data = httpx.get(doc_url).content

prompt = "Summarize this document"
response = client.models.generate_content(
  model="gemini-3-flash-preview",
  contents=[
      types.Part.from_bytes(
        data=doc_data,
        mime_type='application/pdf',
      ),
      prompt])
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# This document presents **AGENTBENCH**, a comprehensive benchmark designed to evaluate Large Language Models (LLMs) as autonomous agents across diverse interactive environments.
#
# ### Core Objectives and Methodology
# The authors argue that while LLMs have mastered traditional NLP tasks, their ability to act as agents—reasoning, decision-making, and executing actions in a multi-turn environment—remains largely unquantified. AGENTBENCH aims to fill this gap by providing:
# *   **8 Distinct Environments:** Categorized into three types: **Code** (OS, Database, Knowledge Graph), **Game** (Digital Card Game, Lateral Thinking Puzzles, House-Holding), and **Web** (Web Shopping, Web Browsing).
# *   **Broad Evaluation:** The study tests **29 different LLMs**, including top-tier commercial APIs (like GPT-4 and Claude) and numerous open-source (OSS) models.
# *   **Unified Toolkit:** A server-client framework that uses Docker to isolate environments and streamline evaluation.
#
# ### Key Findings
# *   **Performance Gap:** There is a significant disparity between top commercial models and OSS competitors. **GPT-4** emerged as the most proficient agent, while many OSS models (even up to 70B parameters) struggled with basic tasks.
# *   **Leading OSS Models:** Within the evaluation scope, `codellama-34b` was the most capable open-source model, though it still trailed behind commercial APIs like `gpt-3.5-turbo`.
# *   **Primary Causes of Failure:**
#     *   **TLE (Task Limit Exceeded):** The most common failure, often caused by models getting stuck in repetitive loops or failing to make progress within the round limit.
#     *   **Poor Instruction Following:** OSS models frequently failed due to "Invalid Format" or "Invalid Action" errors, highlighting a lack of robustness in following environment rules.
# *   **Impact of Training:**
#     *   **Alignment Matters:** Models aligned with high-quality data (e.g., `vicuna-13b`) significantly outperformed their base counterparts (e.g., `llama2-13b`).
#     *   **Ambivalent Code Training:** While code-specific training helps in procedural tasks like web shopping, it can sometimes negatively impact general reasoning and situational awareness in game-based environments.
#
# ### Conclusion
# The document concludes that while LLMs are beginning to show promise as agents, they are far from "practical usability" in complex, multi-step tasks. The authors suggest that improving instruction-following capabilities and training on high-quality multi-round alignment data are the most critical paths toward developing more capable LLM agents.

# %%
doc_url = "https://arxiv.org/pdf/2308.03688"

# Retrieve and encode the PDF byte
doc_data = httpx.get(doc_url).content

prompt = "Extract all the tables from this paper as json objects."
response = client.models.generate_content(
  model="gemini-3-flash-preview",
  contents=[
      types.Part.from_bytes(
        data=doc_data,
        mime_type='application/pdf',
      ),
      prompt])
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ```json
# [
#   {
#     "table_name": "Table 1",
#     "table_caption": "Table 1: AGENTBENCH evaluates 29 API-based or OSS LLMs on LLM-as-Agent challenges. Models annotated with * are evaluated after task weights are computed.",
#     "table_content": [
#       {
#         "Model": "gpt-4 (OpenAI, 2023)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "0613",
#         "Creator": "OpenAI"
#       },
#       {
#         "Model": "gpt-3.5-turbo (OpenAI, 2022)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "0613",
#         "Creator": "OpenAI"
#       },
#       {
#         "Model": "text-davinci-003 (Ouyang et al., 2022)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "-",
#         "Creator": "OpenAI"
#       },
#       {
#         "Model": "text-davinci-002 (Ouyang et al., 2022)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "-",
#         "Creator": "OpenAI"
#       },
#       {
#         "Model": "claude-3* (Anthropic, 2024)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "opus",
#         "Creator": "Anthropic"
#       },
#       {
#         "Model": "claude-2 (Anthropic, 2023b)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "-",
#         "Creator": "Anthropic"
#       },
#       {
#         "Model": "claude (Anthropic, 2023a)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "v1.3",
#         "Creator": "Anthropic"
#       },
#       {
#         "Model": "claude-instant (Anthropic, 2023a)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "v1.1",
#         "Creator": "Anthropic"
#       },
#       {
#         "Model": "chat-bison-001 (Anil et al., 2023)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "-",
#         "Creator": "Google"
#       },
#       {
#         "Model": "glm-4* (Zeng et al., 2022; Du et al., 2022)",
#         "#Size": "N/A",
#         "Form": "api",
#         "Ver.": "-",
#         "Creator": "Tsinghua & Zhipu"
#       },
#       {
#         "Model": "chatglm-6b (Zeng et al., 2022; Du et al., 2022)",
#         "#Size": "6B",
#         "Form": "open",
#         "Ver.": "v1.1",
#         "Creator": "Tsinghua & Zhipu"
#       },
#       {
#         "Model": "codegeex2-6b (Zheng et al., 2023)",
#         "#Size": "6B",
#         "Form": "open",
#         "Ver.": "-",
#         "Creator": "Tsinghua & Zhipu"
#       },
#       {
#         "Model": "codellama-34b (Rozière et al., 2023)",
#         "#Size": "34B",
#         "Form": "open",
#         "Ver.": "instruct",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "codellama-13b (Rozière et al., 2023)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "instruct",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "codellama-7b (Rozière et al., 2023)",
#         "#Size": "7B",
#         "Form": "open",
#         "Ver.": "instruct",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "dolly-12b (Conover et al., 2023)",
#         "#Size": "12B",
#         "Form": "open",
#         "Ver.": "v2",
#         "Creator": "Databricks"
#       },
#       {
#         "Model": "llama2-70b (Touvron et al., 2023)",
#         "#Size": "70B",
#         "Form": "open",
#         "Ver.": "chat",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "llama2-13b (Touvron et al., 2023)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "chat",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "llama2-7b (Touvron et al., 2023)",
#         "#Size": "7B",
#         "Form": "open",
#         "Ver.": "chat",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "guanaco-65b (Dettmers et al., 2023)",
#         "#Size": "65B",
#         "Form": "open",
#         "Ver.": "-",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "guanaco-33b (Dettmers et al., 2023)",
#         "#Size": "33B",
#         "Form": "open",
#         "Ver.": "-",
#         "Creator": "Meta"
#       },
#       {
#         "Model": "vicuna-33b (Chiang et al., 2023)",
#         "#Size": "33B",
#         "Form": "open",
#         "Ver.": "v1.3",
#         "Creator": "LMSYS"
#       },
#       {
#         "Model": "vicuna-13b (Chiang et al., 2023)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "v1.5",
#         "Creator": "LMSYS"
#       },
#       {
#         "Model": "vicuna-7b (Chiang et al., 2023)",
#         "#Size": "7B",
#         "Form": "open",
#         "Ver.": "v1.5",
#         "Creator": "LMSYS"
#       },
#       {
#         "Model": "openchat-13b (Wang et al., 2023a)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "v3.2",
#         "Creator": "Tsinghua"
#       },
#       {
#         "Model": "wizardlm-30b (Xu et al., 2023)",
#         "#Size": "30B",
#         "Form": "open",
#         "Ver.": "v1.0",
#         "Creator": "Microsoft"
#       },
#       {
#         "Model": "wizardlm-13b (Xu et al., 2023)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "v1.0",
#         "Creator": "Microsoft"
#       },
#       {
#         "Model": "koala-13b (Geng et al., 2023)",
#         "#Size": "13B",
#         "Form": "open",
#         "Ver.": "-",
#         "Creator": "UCB"
#       },
#       {
#         "Model": "oasst-12b (LAION, 2023)",
#         "#Size": "12B",
#         "Form": "open",
#         "Ver.": "sft-4",
#         "Creator": "LAION"
#       }
#     ]
#   },
#   {
#     "table_name": "Table 2",
#     "table_caption": "Table 2: Statistics and metrics of 8 environments in AGENTBENCH evaluation. “SR” stands for Success Rate. “#Avg. Round” denotes the estimated number of interacting rounds to solve a single problem. In “#Dev”, and “#Test”, we provide the number of query samples and total expected interacting rounds. Additionally, “Weight^-1” refers to the average score for a task across all models in our evaluation.",
#     "table_content": [
#       {
#         "Parameter": "#Avg. Round",
#         "Operating System": "8",
#         "Data Base": "5",
#         "Knowledge Graph": "15",
#         "Digital Card Game": "30",
#         "Lateral Thinking Puzzle": "25",
#         "House Holding": "35",
#         "Web Shopping": "5",
#         "Web Browsing": "10"
#       },
#       {
#         "Parameter": "Metric",
#         "Operating System": "SR",
#         "Data Base": "SR",
#         "Knowledge Graph": "F1",
#         "Digital Card Game": "Reward",
#         "Lateral Thinking Puzzle": "Game Progress",
#         "House Holding": "SR",
#         "Web Shopping": "Reward",
#         "Web Browsing": "Step SR"
#       },
#       {
#         "Parameter": "#Dev",
#         "Operating System": "26 / 240",
#         "Data Base": "60 / 300",
#         "Knowledge Graph": "20 / 300",
#         "Digital Card Game": "12 / 360",
#         "Lateral Thinking Puzzle": "20 / 500",
#         "House Holding": "20 / 700",
#         "Web Shopping": "80 / 400",
#         "Web Browsing": "31 / 400"
#       },
#       {
#         "Parameter": "#Test",
#         "Operating System": "144 / 1200",
#         "Data Base": "300 / 1500",
#         "Knowledge Graph": "150 / 2250",
#         "Digital Card Game": "20 / 600",
#         "Lateral Thinking Puzzle": "50 / 1250",
#         "House Holding": "50 / 1750",
#         "Web Shopping": "200 / 1000",
#         "Web Browsing": "100 / 1000"
#       },
#       {
#         "Parameter": "Weight^-1",
#         "Operating System": "10.8",
#         "Data Base": "13.0",
#         "Knowledge Graph": "13.9",
#         "Digital Card Game": "12.0",
#         "Lateral Thinking Puzzle": "3.5",
#         "House Holding": "13.0",
#         "Web Shopping": "30.7",
#         "Web Browsing": "11.6"
#       }
#     ]
#   },
#   {
#     "table_name": "Table 3",
#     "table_caption": "Table 3: Test set (standard) results of AGENTBENCH. A clear performance gap exists between top commercial LLMs (e.g., gpt-4) and OSS LLM competitors. “VER” stands for model version; “OA” stands for the overall AGENTBENCH score, a weighted average of all environments (Cf. Section 4.1).",
#     "table_content": [
#       {
#         "LLM Type": "API",
#         "Models": "gpt-4",
#         "VER": "0613",
#         "OA": "4.01",
#         "Operating System": "42.4",
#         "Database": "32.0",
#         "Knowledge Graph": "58.8",
#         "Digital Card Game": "74.5",
#         "Lateral Thinking Puzzle": "16.6",
#         "House Holding": "78.0",
#         "Web Shopping": "61.1",
#         "Web Browsing": "29.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "claude-3",
#         "VER": "opus",
#         "OA": "3.11",
#         "Operating System": "22.9",
#         "Database": "51.7",
#         "Knowledge Graph": "34.6",
#         "Digital Card Game": "44.5",
#         "Lateral Thinking Puzzle": "14.3",
#         "House Holding": "70.0",
#         "Web Shopping": "27.9",
#         "Web Browsing": "26.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "glm-4",
#         "VER": "-",
#         "OA": "2.89",
#         "Operating System": "29.2",
#         "Database": "42.3",
#         "Knowledge Graph": "46.3",
#         "Digital Card Game": "34.1",
#         "Lateral Thinking Puzzle": "14.2",
#         "House Holding": "34.0",
#         "Web Shopping": "61.6",
#         "Web Browsing": "27.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "claude-2",
#         "VER": "-",
#         "OA": "2.49",
#         "Operating System": "18.1",
#         "Database": "27.3",
#         "Knowledge Graph": "41.3",
#         "Digital Card Game": "55.5",
#         "Lateral Thinking Puzzle": "8.4",
#         "House Holding": "54.0",
#         "Web Shopping": "61.4",
#         "Web Browsing": "0.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "claude",
#         "VER": "v1.3",
#         "OA": "2.44",
#         "Operating System": "9.7",
#         "Database": "22.0",
#         "Knowledge Graph": "38.9",
#         "Digital Card Game": "40.9",
#         "Lateral Thinking Puzzle": "8.2",
#         "House Holding": "58.0",
#         "Web Shopping": "55.7",
#         "Web Browsing": "25.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "gpt-3.5-turbo",
#         "VER": "0613",
#         "OA": "2.32",
#         "Operating System": "32.6",
#         "Database": "36.7",
#         "Knowledge Graph": "25.9",
#         "Digital Card Game": "33.7",
#         "Lateral Thinking Puzzle": "10.5",
#         "House Holding": "16.0",
#         "Web Shopping": "64.1",
#         "Web Browsing": "20.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "text-davinci-003",
#         "VER": "-",
#         "OA": "1.71",
#         "Operating System": "20.1",
#         "Database": "16.3",
#         "Knowledge Graph": "34.9",
#         "Digital Card Game": "3.0",
#         "Lateral Thinking Puzzle": "7.1",
#         "House Holding": "20.0",
#         "Web Shopping": "61.7",
#         "Web Browsing": "26.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "claude-instant",
#         "VER": "v1.1",
#         "OA": "1.60",
#         "Operating System": "16.7",
#         "Database": "18.0",
#         "Knowledge Graph": "20.8",
#         "Digital Card Game": "5.9",
#         "Lateral Thinking Puzzle": "12.6",
#         "House Holding": "30.0",
#         "Web Shopping": "49.7",
#         "Web Browsing": "4.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "chat-bison-001",
#         "VER": "-",
#         "OA": "1.39",
#         "Operating System": "9.7",
#         "Database": "19.7",
#         "Knowledge Graph": "23.0",
#         "Digital Card Game": "16.6",
#         "Lateral Thinking Puzzle": "4.4",
#         "House Holding": "18.0",
#         "Web Shopping": "60.5",
#         "Web Browsing": "12.0"
#       },
#       {
#         "LLM Type": "API",
#         "Models": "text-davinci-002",
#         "VER": "-",
#         "OA": "1.25",
#         "Operating System": "8.3",
#         "Database": "16.7",
#         "Knowledge Graph": "41.5",
#         "Digital Card Game": "11.8",
#         "Lateral Thinking Puzzle": "0.5",
#         "House Holding": "16.0",
#         "Web Shopping": "56.3",
#         "Web Browsing": "9.0"
#       },
#       {
#         "LLM Type": "OSS (Large)",
#         "Models": "llama-2-70b",
#         "VER": "chat",
#         "OA": "0.78",
#         "Operating System": "9.7",
#         "Database": "13.0",
#         "Knowledge Graph": "8.0",
#         "Digital Card Game": "21.3",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "2.0",
#         "Web Shopping": "5.6",
#         "Web Browsing": "19.0"
#       },
#       {
#         "LLM Type": "OSS (Large)",
#         "Models": "guanaco-65b",
#         "VER": "-",
#         "OA": "0.54",
#         "Operating System": "8.3",
#         "Database": "14.7",
#         "Knowledge Graph": "1.9",
#         "Digital Card Game": "0.1",
#         "Lateral Thinking Puzzle": "1.5",
#         "House Holding": "12.0",
#         "Web Shopping": "0.9",
#         "Web Browsing": "10.0"
#       },
#       {
#         "LLM Type": "OSS (Medium)",
#         "Models": "codellama-34b",
#         "VER": "instruct",
#         "OA": "0.96",
#         "Operating System": "2.8",
#         "Database": "14.0",
#         "Knowledge Graph": "23.5",
#         "Digital Card Game": "8.4",
#         "Lateral Thinking Puzzle": "0.7",
#         "House Holding": "4.0",
#         "Web Shopping": "52.1",
#         "Web Browsing": "20.0"
#       },
#       {
#         "LLM Type": "OSS (Medium)",
#         "Models": "vicuna-33b",
#         "VER": "v1.3",
#         "OA": "0.73",
#         "Operating System": "15.3",
#         "Database": "11.0",
#         "Knowledge Graph": "1.2",
#         "Digital Card Game": "16.3",
#         "Lateral Thinking Puzzle": "1.0",
#         "House Holding": "6.0",
#         "Web Shopping": "23.9",
#         "Web Browsing": "7.0"
#       },
#       {
#         "LLM Type": "OSS (Medium)",
#         "Models": "wizardlm-30b",
#         "VER": "v1.0",
#         "OA": "0.46",
#         "Operating System": "13.9",
#         "Database": "12.7",
#         "Knowledge Graph": "2.9",
#         "Digital Card Game": "0.3",
#         "Lateral Thinking Puzzle": "1.8",
#         "House Holding": "6.0",
#         "Web Shopping": "4.4",
#         "Web Browsing": "1.0"
#       },
#       {
#         "LLM Type": "OSS (Medium)",
#         "Models": "guanaco-33b",
#         "VER": "-",
#         "OA": "0.39",
#         "Operating System": "11.1",
#         "Database": "9.3",
#         "Knowledge Graph": "3.2",
#         "Digital Card Game": "0.3",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "6.0",
#         "Web Shopping": "6.2",
#         "Web Browsing": "5.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "vicuna-13b",
#         "VER": "v1.5",
#         "OA": "0.93",
#         "Operating System": "10.4",
#         "Database": "6.7",
#         "Knowledge Graph": "9.4",
#         "Digital Card Game": "0.1",
#         "Lateral Thinking Puzzle": "8.0",
#         "House Holding": "8.0",
#         "Web Shopping": "41.7",
#         "Web Browsing": "12.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "llama-2-13b",
#         "VER": "chat",
#         "OA": "0.77",
#         "Operating System": "4.2",
#         "Database": "11.7",
#         "Knowledge Graph": "3.6",
#         "Digital Card Game": "26.4",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "6.0",
#         "Web Shopping": "25.3",
#         "Web Browsing": "13.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "openchat-13b",
#         "VER": "v3.2",
#         "OA": "0.70",
#         "Operating System": "15.3",
#         "Database": "12.3",
#         "Knowledge Graph": "5.5",
#         "Digital Card Game": "0.1",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "46.9",
#         "Web Browsing": "15.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "wizardlm-13b",
#         "VER": "v1.2",
#         "OA": "0.66",
#         "Operating System": "9.0",
#         "Database": "12.7",
#         "Knowledge Graph": "1.7",
#         "Digital Card Game": "1.9",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "10.0",
#         "Web Shopping": "43.7",
#         "Web Browsing": "12.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "vicuna-7b",
#         "VER": "v1.5",
#         "OA": "0.56",
#         "Operating System": "9.7",
#         "Database": "8.7",
#         "Knowledge Graph": "2.5",
#         "Digital Card Game": "0.3",
#         "Lateral Thinking Puzzle": "6.4",
#         "House Holding": "0.0",
#         "Web Shopping": "2.2",
#         "Web Browsing": "9.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "codellama-13b",
#         "VER": "instruct",
#         "OA": "0.56",
#         "Operating System": "3.5",
#         "Database": "9.7",
#         "Knowledge Graph": "10.4",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "43.8",
#         "Web Browsing": "14.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "codellama-7b",
#         "VER": "instruct",
#         "OA": "0.50",
#         "Operating System": "4.9",
#         "Database": "12.7",
#         "Knowledge Graph": "8.2",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "2.0",
#         "Web Shopping": "25.2",
#         "Web Browsing": "12.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "koala-13b",
#         "VER": "-",
#         "OA": "0.34",
#         "Operating System": "3.5",
#         "Database": "5.0",
#         "Knowledge Graph": "0.4",
#         "Digital Card Game": "0.1",
#         "Lateral Thinking Puzzle": "4.4",
#         "House Holding": "0.0",
#         "Web Shopping": "3.9",
#         "Web Browsing": "7.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "llama-2-7b",
#         "VER": "chat",
#         "OA": "0.34",
#         "Operating System": "4.2",
#         "Database": "8.0",
#         "Knowledge Graph": "2.1",
#         "Digital Card Game": "6.9",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "11.6",
#         "Web Browsing": "7.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "codegeex2-6b",
#         "VER": "-",
#         "OA": "0.27",
#         "Operating System": "1.4",
#         "Database": "0.0",
#         "Knowledge Graph": "4.8",
#         "Digital Card Game": "0.3",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "20.9",
#         "Web Browsing": "11.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "dolly-12b",
#         "VER": "v2",
#         "OA": "0.14",
#         "Operating System": "0.0",
#         "Database": "0.0",
#         "Knowledge Graph": "0.0",
#         "Digital Card Game": "0.1",
#         "Lateral Thinking Puzzle": "1.2",
#         "House Holding": "0.0",
#         "Web Shopping": "0.4",
#         "Web Browsing": "9.0"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "chatglm-6b",
#         "VER": "v1.1",
#         "OA": "0.11",
#         "Operating System": "4.9",
#         "Database": "0.3",
#         "Knowledge Graph": "0.0",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "0.5",
#         "Web Browsing": "4.9"
#       },
#       {
#         "LLM Type": "OSS (Small)",
#         "Models": "oasst-12b",
#         "VER": "sft-4",
#         "OA": "0.03",
#         "Operating System": "1.4",
#         "Database": "0.0",
#         "Knowledge Graph": "0.0",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "0.3",
#         "Web Browsing": "1.0"
#       }
#     ]
#   },
#   {
#     "table_name": "Table 4",
#     "table_caption": "Table 4: Portions of different types of execution outcomes in 8 tasks averaged across all models. (CLE: Context Limit Exceeded, TLE: Task Limit Exceeded).",
#     "table_content": [
#       {
#         "Outcome": "Completed",
#         "Operating System": "75.0",
#         "Data Base": "37.9",
#         "Knowledge Graph": "30.1",
#         "Digital Card Game": "51.2",
#         "Lateral Thinking Puzzle": "14.0",
#         "House Holding": "13.1",
#         "Web Shopping": "54.9",
#         "Web Browsing": "56.6"
#       },
#       {
#         "Outcome": "CLE",
#         "Operating System": "0.1",
#         "Data Base": "0.7",
#         "Knowledge Graph": "2.0",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "3.5",
#         "House Holding": "0.7",
#         "Web Shopping": "0.0",
#         "Web Browsing": "0.0"
#       },
#       {
#         "Outcome": "Invalid Format",
#         "Operating System": "0.0",
#         "Data Base": "53.3",
#         "Knowledge Graph": "0.0",
#         "Digital Card Game": "38.5",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "0.0",
#         "Web Shopping": "17.2",
#         "Web Browsing": "0.0"
#       },
#       {
#         "Outcome": "Invalid Action",
#         "Operating System": "0.9",
#         "Data Base": "0.0",
#         "Knowledge Graph": "0.0",
#         "Digital Card Game": "10.2",
#         "Lateral Thinking Puzzle": "0.0",
#         "House Holding": "64.1",
#         "Web Shopping": "0.0",
#         "Web Browsing": "8.4"
#       },
#       {
#         "Outcome": "TLE",
#         "Operating System": "23.9",
#         "Data Base": "8.0",
#         "Knowledge Graph": "67.9",
#         "Digital Card Game": "0.0",
#         "Lateral Thinking Puzzle": "82.5",
#         "House Holding": "22.1",
#         "Web Shopping": "27.8",
#         "Web Browsing": "35.0"
#       }
#     ]
#   },
#   {
#     "table_name": "Table 5",
#     "table_caption": "Table 5: Re-annotated data tested on gpt-4 and gpt-3.5-turbo compared with the original data.",
#     "table_content": [
#       {
#         "Model": "gpt-4",
#         "type": "original",
#         "SELECT": "0.32",
#         "INSERT": "0.32",
#         "UPDATE": "0.32"
#       },
#       {
#         "Model": "gpt-3.5-turbo",
#         "type": "original",
#         "SELECT": "0.21",
#         "INSERT": "0.23",
#         "UPDATE": "0.66"
#       },
#       {
#         "Model": "gpt-4",
#         "type": "new",
#         "SELECT": "-",
#         "INSERT": "0.27",
#         "UPDATE": "0.66"
#       },
#       {
#         "Model": "gpt-3.5-turbo",
#         "type": "new",
#         "SELECT": "-",
#         "INSERT": "0.19",
#         "UPDATE": "0.92"
#       }
#     ]
#   },
#   {
#     "table_name": "Table 6",
#     "table_caption": "Table 6: Comparison of Outcome distribution for 2 types of models.",
#     "table_content": [
#       {
#         "Model Category": "Commercial API-based Models",
#         "Completed": "61.5%",
#         "Context Limit Exceeded": "3.0%",
#         "Invalid Format": "6.0%",
#         "Invalid Action": "4.6%",
#         "Task Limit Exceeded": "24.9%"
#       },
#       {
#         "Model Category": "Open-Sourced Models",
#         "Completed": "39.1%",
#         "Context Limit Exceeded": "0.0%",
#         "Invalid Format": "10.4%",
#         "Invalid Action": "13.6%",
#         "Task Limit Exceeded": "36.9%"
#       }
#     ]
#   }
# ]
# ```

# %% [markdown]
# ![](sample_image_from_paper_agent_bench.png)

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

my_file = client.files.upload(file="./assets-resources/sample_image_from_paper_agent_bench.png")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[my_file, f"Explain this figure in a few bullet points."],
)

print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Based on Figure 1, here is an explanation of the key findings from the AgentBench evaluation:
#
# *   **Overall Performance Gap:** There is a significant performance disparity between commercial, API-based LLMs (orange) and open-source (OSS) LLMs (green). Commercial models have an average score of 2.15, while open-source models average only 0.51.
# *   **GPT-4 Dominance:** GPT-4 is the clear leader across all categories, achieving an overall score of 4.01—nearly double that of the next best commercial models (Claude-2 and GPT-3.5-turbo) and vastly higher than any open-source model.
# *   **Diverse Task Evaluation:** The radar chart (a) shows that LLMs were tested across eight varied environments, including technical tasks (Operating System, Database), reasoning tasks (Lateral Thinking Puzzles), and interactive tasks (Web Shopping, House-holding).
# *   **Relative Proficiency:** While top-tier models like GPT-4 show high relative performance (stretching toward the edges of the radar chart), many other models struggle significantly in specific complex environments like "Operating System" or "Database" interaction.
# *   **Distance to Practical Usability:** Despite the proficiency shown by top models, the overall scores (mostly below 4 out of an unspecified higher potential) suggest that a significant gap remains before these LLMs can be considered fully reliable for practical, real-world agent tasks.
