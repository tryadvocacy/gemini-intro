# %% [markdown]
# # Gemini for Text Generation

# %% [markdown]
# Can you read this???

# %%
# !pip install -q -U google-genai

# %%
from google import genai
import os
# from dotenv import load_dotenv

# load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# It learns patterns from data to make intelligent decisions.

# %%
from IPython.display import Markdown

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in 200 words."
)

Markdown(response.text)
# Out:
# AI works by recognizing complex patterns in vast amounts of data. This process begins with **training**, where an AI model—often a type of machine learning algorithm—is fed massive datasets. For instance, to identify a cat, it's shown millions of images labeled "cat" or "not cat."
#
# During training, the algorithm learns to identify key characteristics and relationships within the data. It iteratively adjusts its internal parameters, refining its understanding. Modern AI frequently uses **neural networks**, structures inspired by the human brain, which consist of layers of interconnected processing units that collaboratively analyze complex inputs.
#
# Once trained, the AI model can make predictions or decisions on new, unseen data. When presented with a fresh image, it applies its learned patterns to determine if it's a cat, translate a sentence, recommend a product, or even drive a car. Essentially, AI transforms data into actionable insights, enabling machines to perform tasks that traditionally require human intelligence through sophisticated pattern recognition and data-driven decision-making.

# %% [markdown]
# # Gemini for Image Understanding

# %% [markdown]
# <img src="./assets-resources/sample-image.png" width=40%>

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

my_file = client.files.upload(file="./assets-resources/sample-image.png")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[my_file, "Caption this image in one small sentence."],
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# This image illustrates the natively multimodal architecture of the Gemini model.

# %% [markdown]
# ## To pass image data inline

# %%
from google.genai import types

with open('./assets-resources/sample-image.png', 'rb') as f:
    image_bytes = f.read()

response = client.models.generate_content(
model='gemini-2.5-flash',
contents=[
    types.Part.from_bytes(
    data=image_bytes,
    mime_type='image/png',
    ),
    'What is the diagram in this picture?Answer it concisely.'
]
)

print(response.text)
# Out:
# The diagram illustrates how Gemini models support interleaved sequences of text, image, audio, and video as inputs, which are processed by a Transformer and can output interleaved image and text.

# %% [markdown]
# See more examples for working with images in Gemini [here](https://ai.google.dev/gemini-api/docs/image-understanding).

# %% [markdown]
# # Document Understanding

# %%
from google import genai
from google.genai import types
import httpx

client = genai.Client(api_key=gemini_api_key)

doc_url = "https://arxiv.org/pdf/1706.03762"

# Retrieve and encode the PDF byte
doc_data = httpx.get(doc_url).content

prompt = "Summarize this document in bullet points"
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=[
      types.Part.from_bytes(
        data=doc_data,
        mime_type='application/pdf',
      ),
      prompt])
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Here's a summary of the "Attention Is All You Need" paper in bullet points:
#
# *   **Core Proposal:** Introduces **The Transformer**, a novel neural network architecture for sequence transduction models that relies *solely* on attention mechanisms, completely dispensing with recurrence and convolutions.
# *   **Motivation:** Existing models (RNNs, CNNs) have limitations:
#     *   **Recurrent models:** Inherently sequential computation, limiting parallelization and becoming critical at longer sequence lengths.
#     *   **Convolutional models (ByteNet, ConvS2S):** Path length between distant positions grows linearly or logarithmically, making long-range dependencies harder to learn.
# *   **Key Innovation - Self-Attention:**
#     *   Allows modeling dependencies between positions in a single sequence (intra-attention).
#     *   Offers a **constant number of operations** to relate signals from any two positions, regardless of distance (compared to O(n) for RNNs or O(log n) for ConvNets).
#     *   **Multi-Head Attention:** Linearly projects queries, keys, and values `h` times with different learned projections, performs scaled dot-product attention in parallel for each "head," concatenates outputs, and projects again. This allows the model to jointly attend to information from different representation subspaces.
#     *   **Scaled Dot-Product Attention:** Computes output as `softmax(QKT / sqrt(dk))V`. Scaling by `sqrt(dk)` prevents dot products from growing too large, which can push softmax into regions with tiny gradients.
# *   **Architecture Details:**
#     *   **Encoder-Decoder Structure:** Standard for sequence transduction.
#     *   **Encoder:** Stack of N=6 identical layers, each with two sub-layers: a Multi-Head Self-Attention mechanism and a position-wise fully connected feed-forward network.
#     *   **Decoder:** Stack of N=6 identical layers, with three sub-layers: a Masked Multi-Head Self-Attention (prevents attending to future positions), a Multi-Head Attention over the encoder's output, and a position-wise fully connected feed-forward network.
#     *   **Residual Connections & Layer Normalization:** Used around each sub-layer.
#     *   **Positional Encoding:** Since there are no recurrent or convolutional layers, sinusoidal positional encodings (`sin` and `cos` functions of different frequencies) are added to the input embeddings to inject information about token positions.
# *   **Advantages of Self-Attention (Why):**
#     *   **Computational Complexity:** Faster per layer for shorter sequences (`n < dmodel`).
#     *   **Parallelization:** Requires a constant number of sequential operations (O(1)) per layer, enabling much higher parallelization during training.
#     *   **Path Length:** Reduces the path length between any two positions to a constant, making it easier to learn long-range dependencies.
# *   **Experimental Results (Machine Translation - WMT 2014):**
#     *   **English-to-German:** Achieved 28.4 BLEU (state-of-the-art), surpassing previous best models and ensembles by over 2 BLEU.
#     *   **English-to-French:** Achieved 41.8 BLEU (state-of-the-art single-model), with a small fraction of the training costs of previous best models.
#     *   **Training Cost:** Significantly more parallelizable and requires significantly less time to train (e.g., 3.5 days on eight GPUs for the "big" model).
# *   **Generalization:** Successfully applied to English constituency parsing, showing good performance even with limited task-specific tuning.
# *   **Key Findings from Ablation Studies:**
#     *   Multi-head attention is crucial; single-head performs worse.
#     *   Scaling dot products by `sqrt(dk)` is important.
#     *   Bigger models generally perform better.
#     *   Sinusoidal positional encodings perform nearly identically to learned ones.
# *   **Conclusion:** The Transformer sets a new state-of-the-art for sequence transduction tasks, demonstrating that attention alone can be highly effective, efficient, and generalize well across tasks.
# *   **Code Availability:** The code used for training and evaluation is available on GitHub/TensorFlow.
#
# ---
# *Note: As per the instruction on the first page, Google grants permission to reproduce tables and figures for journalistic or scholarly works.*

# %% [markdown]
# ## For locally stored pdfs

# %%
from google import genai
from google.genai import types
import pathlib
import httpx

client = genai.Client(api_key=gemini_api_key)

# Uncomment this to download from the internet and save it locally
# doc_url = "https://discovery.ucl.ac.uk/id/eprint/10089234/1/343019_3_art_0_py4t4l_convrt.pdf"
# filepath = pathlib.Path('./assets-resources/prompt-eng-guide-google.pdf')
# filepath.write_bytes(httpx.get(doc_url).content)

# This example assumes the pdf is stored locally
# Retrieve and encode the PDF byte
filepath = pathlib.Path('./assets-resources/prompt-eng-guide-google.pdf')

prompt = "Write markdown style 3 page report on this prompt engineering guide with just the practical tips and relevant information."
response = client.models.generate_content(
  model="gemini-3.1-pro-preview",
  contents=[
      types.Part.from_bytes(
        data=filepath.read_bytes(),
        mime_type='application/pdf',
      ),
      prompt])
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# # A Practical Guide to Prompt Engineering: Actionable Tips and Techniques
#
# This report synthesizes the core, actionable strategies from Google's "Prompt Engineering" whitepaper. It strips away the foundational theory to focus strictly on configuration settings, structural techniques, advanced reasoning paradigms, and best practices for interacting with Large Language Models (LLMs).
#
# ---
#
# ## 1. LLM Output Configuration
# Before writing the prompt, tuning the model's sampling controls is critical for determining the nature of your output.
#
# *   **Temperature**: Controls the randomness of the output.
#     *   *Tip:* Set to **0** for deterministic, factual tasks (e.g., math problems, data extraction).
#     *   *Tip:* Increase the temperature (e.g., **0.8 - 1.0**) for creative, diverse outputs (e.g., brainstorming, creative writing).
# *   **Top-K**: Restricts the model to select from the top *K* most likely next tokens.
#     *   *Tip:* Use lower Top-K (e.g., **20**) for factual, restrained output. Use higher Top-K (e.g., **40**) for more variety.
# *   **Top-P (Nucleus Sampling)**: Selects from tokens whose cumulative probability does not exceed *P*.
#     *   *Tip:* Lower Top-P (e.g., **0.5**) trims less likely options, ensuring tighter logic. Higher Top-P (e.g., **0.99**) allows for edge-case vocabulary.
#
# **Practical Starting Points:**
# *   **Coherent but slightly creative:** Temp: 0.2, Top-P: 0.95, Top-K: 30
# *   **Highly creative:** Temp: 0.9, Top-P: 0.99, Top-K: 40
# *   **Strictly factual:** Temp: 0.0, Top-K: 1
#
# ---
#
# ## 2. Core Prompting Techniques
#
# ### Zero-Shot and Few-Shot Prompting
# *   **Zero-Shot**: Giving the model a task with no examples. Best for simple, straightforward tasks.
# *   **Few-Shot**: Providing 3 to 5 examples of the desired input/output pairing.
#     *   *Tip:* Always include "edge cases" in your examples so the model knows how to handle unexpected inputs.
#     *   *Tip:* For classification tasks, **mix up the order** of the classes in your examples to prevent the model from overfitting to a specific pattern.
#
# ### The Triad: System, Contextual, and Role Prompting
# Combine these three approaches for highly tailored responses:
# 1.  **System Prompting**: Defines the fundamental capability and rules (e.g., *"Return only valid JSON,"* or *"You should be respectful in your answer"*).
# 2.  **Contextual Prompting**: Provides immediate, dynamic background information (e.g., *"Context: You are writing a blog about retro 80's arcade games."*).
# 3.  **Role Prompting**: Assigns an identity to dictate tone and style (e.g., *"Act as a travel guide..."* or *"Act as a senior Python developer..."*).
#     *   *Effective Styles to try:* Confrontational, Descriptive, Formal, Humorous, Influential, Persuasive.
#
# ---
#
# ## 3. Advanced Reasoning Strategies
#
# When standard prompting fails on complex logic or math, employ these advanced frameworks:
#
# ### Chain of Thought (CoT)
# Forces the model to generate intermediate reasoning steps before providing an answer.
# *   **How to use:** Simply append the phrase ***"Let's think step by step"*** to your prompt.
# *   **Best Practice:** Always set **Temperature to 0** for CoT, as reasoning requires strict logic rather than creative guessing.
# *   **Formatting:** Require the model to place the final answer *after* the reasoning steps.
#
# ### Self-Consistency
# A method to double-check the model's logic by combining CoT with majority voting.
# *   **How to use:** Send the exact same CoT prompt to the model multiple times with a *higher temperature*. Extract the final answer from each generation, and use the most commonly occurring answer as the absolute truth.
#
# ### Step-Back Prompting
# Improves accuracy by forcing the LLM to zoom out and establish facts before solving a specific issue.
# *   **How to use:** First, prompt the LLM to answer a broad, foundational question about the topic. Second, pass that general answer as *context* into your specific task prompt.
#
# ### ReAct (Reason & Act)
# A paradigm for allowing LLMs to solve complex tasks by combining reasoning with external tool use (like APIs, search engines, or code interpreters).
# *   **How to use:** Use frameworks like LangChain to create an "Agent." The LLM outputs a "Thought," determines an "Action" (e.g., Google Search), observes the result, and loops until it reaches a "Final Answer."
#
# ---
#
# ## 4. Code Generation and Handling
#
# LLMs are highly capable developers if guided correctly.
# *   **Generating Code:** Explicitly state the programming language and require comments. *Always test generated code.*
# *   **Translating Code:** Pass a snippet (e.g., Bash) and ask the model to rewrite it in another language (e.g., Python), maintaining the exact functionality.
# *   **Debugging Code:** Don't just ask "fix this." Provide the broken code **and** the exact terminal traceback/error message. Ask the model to explain *why* it broke and provide the corrected code.
#
# ---
#
# ## 5. Essential Best Practices
#
# ### Formatting and Language
# *   **Use Action Verbs:** Start prompts with strong commands: *Act, Analyze, Classify, Compare, Extract, Parse, Summarize, Translate.*
# *   **Instructions over Constraints:** LLMs respond better to positive instructions (what *to* do) rather than negative constraints (what *not* to do).
#     *   *Bad:* "Do not list video game names."
#     *   *Good:* "Only discuss the console, the company who made it, and total sales."
# *   **Use Variables:** Make prompts dynamic and reusable by using brackets for variables (e.g., `{city} = "Amsterdam"`).
# *   **Control Token Length:** If you need brief outputs, explicitly state it (e.g., *"Explain in a tweet-length message"*).
#
# ### Structuring Output (JSON and Schemas)
# Returning data in JSON format eliminates hallucinations and makes outputs programmatically usable.
# *   **JSON Prompts:** Explicitly define the JSON structure in your prompt using a `Schema:` block.
# *   **Provide Input Schemas:** Don't just format the output; format your *input*. Feed the LLM a JSON schema defining the attributes it should read, reducing the chance of it misinterpreting raw text.
# *   **Fixing Broken JSON:** Because JSON is verbose, it can hit the token limit and cut off abruptly, leaving missing brackets. Use Python libraries like `json-repair` to automatically fix malformed LLM outputs.
#
# ### Document and Track Your Prompts
# Prompt engineering is an iterative, scientific process. Track your experiments meticulously using a standard framework (like a Google Sheet) containing:
# 1.  **Prompt Name & Version**
# 2.  **Goal** (One-sentence explanation)
# 3.  **Model Used**
# 4.  **Settings** (Temperature, Top-K, Top-P, Token Limit)
# 5.  **Exact Prompt Text**
# 6.  **Generated Output**
#
# *Tip: Save prompts separate from your application codebase, and use automated evaluation procedures (like BLEU or ROUGE metrics) to score and choose the best prompt variants.*

# %%
# live coding sesh!

# %% [markdown]
# # can germini 2.5 flash be used to pull all tables, of different format, in  a pdf, say of around 100 pages? or is there a more efficient way, model or steps you could recommend? Some table have lines, others do not.

# %% [markdown]
# <img src="./table1-paper.png" width=50%>

# %%
from google.genai import types

pdf_figure_image_path = "./table1-paper.png"

with open(pdf_figure_image_path, 'rb') as f:
    image_bytes = f.read()

response = client.models.generate_content(
model='gemini-2.5-flash',
contents=[
    types.Part.from_bytes(
    data=image_bytes,
    mime_type='image/png',
    ),
    'Extract the full table in this example as a dictionary.'
]
)

print(response.text)
# Out:
# ```json
# [
#   {
#     "Model": "gpt-4 (OpenAI, 2023)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "0613",
#     "Creator": "OpenAI"
#   },
#   {
#     "Model": "gpt-3.5-turbo (OpenAI, 2022)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "0613",
#     "Creator": "OpenAI"
#   },
#   {
#     "Model": "text-davinci-003 (Ouyang et al., 2022)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "-",
#     "Creator": "OpenAI"
#   },
#   {
#     "Model": "text-davinci-002 (Ouyang et al., 2022)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "-",
#     "Creator": "OpenAI"
#   },
#   {
#     "Model": "claude-2 (Anthropic, 2023b)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "-",
#     "Creator": "Anthropic"
#   },
#   {
#     "Model": "claude (Anthropic, 2023a)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "v1.3",
#     "Creator": "Anthropic"
#   },
#   {
#     "Model": "claude-instant (Anthropic, 2023a)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "v1.1",
#     "Creator": "Anthropic"
#   },
#   {
#     "Model": "chat-bison-001 (Anil et al., 2023)",
#     "#Size": "N/A",
#     "Form": "api",
#     "Ver.": "-",
#     "Creator": "Google"
#   },
#   {
#     "Model": "chatglm-6b (Zeng et al., 2022; Du et al., 2022)",
#     "#Size": "6B",
#     "Form": "open",
#     "Ver.": "v1.1",
#     "Creator": "Tsinghua"
#   },
#   {
#     "Model": "codegeex2-6b (Zheng et al., 2023)",
#     "#Size": "6B",
#     "Form": "open",
#     "Ver.": "-",
#     "Creator": "& Zhipu"
#   },
#   {
#     "Model": "codellama-34b (Rozière et al., 2023)",
#     "#Size": "34B",
#     "Form": "open instruct",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "codellama-13b (Rozière et al., 2023)",
#     "#Size": "13B",
#     "Form": "open instruct",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "codellama-7b (Rozière et al., 2023)",
#     "#Size": "7B",
#     "Form": "open instruct",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "dolly-12b (Conover et al., 2023)",
#     "#Size": "12B",
#     "Form": "open",
#     "Ver.": "v2",
#     "Creator": "Databricks"
#   },
#   {
#     "Model": "llama2-70b (Touvron et al., 2023)",
#     "#Size": "70B",
#     "Form": "open chat",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "llama2-13b (Touvron et al., 2023)",
#     "#Size": "13B",
#     "Form": "open chat",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "llama2-7b (Touvron et al., 2023)",
#     "#Size": "7B",
#     "Form": "open chat",
#     "Ver.": null,
#     "Creator": "Meta"
#   },
#   {
#     "Model": "guanaco-65b (Dettmers et al., 2023)",
#     "#Size": "65B",
#     "Form": "open",
#     "Ver.": "-",
#     "Creator": "Meta"
#   },
#   {
#     "Model": "guanaco-33b (Dettmers et al., 2023)",
#     "#Size": "33B",
#     "Form": "open",
#     "Ver.": "-",
#     "Creator": "Meta"
#   },
#   {
#     "Model": "vicuna-33b (Chiang et al., 2023)",
#     "#Size": "33B",
#     "Form": "open",
#     "Ver.": "v1.3",
#     "Creator": "LMSYS"
#   },
#   {
#     "Model": "vicuna-13b (Chiang et al., 2023)",
#     "#Size": "13B",
#     "Form": "open",
#     "Ver.": "v1.5",
#     "Creator": "LMSYS"
#   },
#   {
#     "Model": "vicuna-7b (Chiang et al., 2023)",
#     "#Size": "7B",
#     "Form": "open",
#     "Ver.": "v1.5",
#     "Creator": "LMSYS"
#   },
#   {
#     "Model": "openchat-13b (Wang et al., 2023a)",
#     "#Size": "13B",
#     "Form": "open",
#     "Ver.": "v3.2",
#     "Creator": "Tsinghua"
#   },
#   {
#     "Model": "wizardlm-30b (Xu et al., 2023)",
#     "#Size": "30B",
#     "Form": "open",
#     "Ver.": "v1.0",
#     "Creator": "Microsoft"
#   },
#   {
#     "Model": "wizardlm-13b (Xu et al., 2023)",
#     "#Size": "13B",
#     "Form": "open",
#     "Ver.": "v1.0",
#     "Creator": "Microsoft"
#   },
#   {
#     "Model": "koala-13b (Geng et al., 2023)",
#     "#Size": "13B",
#     "Form": "open",
#     "Ver.": "-",
#     "Creator": "UCB"
#   },
#   {
#     "Model": "oasst-12b (LAION, 2023)",
#     "#Size": "12B",
#     "Form": "open",
#     "Ver.": "sft-4",
#     "Creator": "LAION"
#   }
# ]
# ```

# %%
import pandas as pd
import json

def extract_table_to_dataframe(json_str):
    """
    Convert the JSON table output from Gemini into a pandas DataFrame.
    
    Args:
        json_str (str): JSON string containing the table data, expected to be wrapped in ```json
        
    Returns:
        pd.DataFrame: DataFrame containing the table data
    """
    # Clean the string by removing ```json and ``` if present
    cleaned_str = json_str.strip()
    if cleaned_str.startswith('```json'):
        cleaned_str = cleaned_str[7:]
    if cleaned_str.endswith('```'):
        cleaned_str = cleaned_str[:-3]
    cleaned_str = cleaned_str.strip()
    
    # Parse the JSON string into a Python dictionary
    data = json.loads(cleaned_str)
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    return df

# Example usage:
df = extract_table_to_dataframe(response.text)
df
# Out:
#                                               Model #Size           Form  \
# 0                              gpt-4 (OpenAI, 2023)   N/A            api
# 1                      gpt-3.5-turbo (OpenAI, 2022)   N/A            api
# 2            text-davinci-003 (Ouyang et al., 2022)   N/A            api
# 3            text-davinci-002 (Ouyang et al., 2022)   N/A            api
# 4                       claude-2 (Anthropic, 2023b)   N/A            api
# 5                         claude (Anthropic, 2023a)   N/A            api
# 6                 claude-instant (Anthropic, 2023a)   N/A            api
# 7                chat-bison-001 (Anil et al., 2023)   N/A            api
# 8   chatglm-6b (Zeng et al., 2022; Du et al., 2022)    6B           open
# 9                 codegeex2-6b (Zheng et al., 2023)    6B           open
# 10             codellama-34b (Rozière et al., 2023)   34B  open instruct
# 11             codellama-13b (Rozière et al., 2023)   13B  open instruct
# 12              codellama-7b (Rozière et al., 2023)    7B  open instruct
# 13                 dolly-12b (Conover et al., 2023)   12B           open
# 14                llama2-70b (Touvron et al., 2023)   70B      open chat
# 15                llama2-13b (Touvron et al., 2023)   13B      open chat
# 16                 llama2-7b (Touvron et al., 2023)    7B      open chat
# 17              guanaco-65b (Dettmers et al., 2023)   65B           open
# 18              guanaco-33b (Dettmers et al., 2023)   33B           open
# 19                 vicuna-33b (Chiang et al., 2023)   33B           open
# 20                 vicuna-13b (Chiang et al., 2023)   13B           open
# 21                  vicuna-7b (Chiang et al., 2023)    7B           open
# 22                openchat-13b (Wang et al., 2023a)   13B           open
# 23                   wizardlm-30b (Xu et al., 2023)   30B           open
# 24                   wizardlm-13b (Xu et al., 2023)   13B           open
# 25                    koala-13b (Geng et al., 2023)   13B           open
# 26                          oasst-12b (LAION, 2023)   12B           open
#
#      Ver.     Creator
# 0    0613      OpenAI
# 1    0613      OpenAI
# 2       -      OpenAI
# 3       -      OpenAI
# 4       -   Anthropic
# 5    v1.3   Anthropic
# 6    v1.1   Anthropic
# 7       -      Google
# 8    v1.1    Tsinghua
# 9       -     & Zhipu
# 10   None        Meta
# 11   None        Meta
# 12   None        Meta
# 13     v2  Databricks
# 14   None        Meta
# 15   None        Meta
# 16   None        Meta
# 17      -        Meta
# 18      -        Meta
# 19   v1.3       LMSYS
# 20   v1.5       LMSYS
# 21   v1.5       LMSYS
# 22   v3.2    Tsinghua
# 23   v1.0   Microsoft
# 24   v1.0   Microsoft
# 25      -         UCB
# 26  sft-4       LAION

# %%
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any
from enum import Enum

class Table(BaseModel):
    table_title: str = Field(description="title of the figure or table")
    table_contents: dict = Field(description="the data within the table as a dictionary")

prompt = f"Extract the table 1 from this paper:"
# Example usage with the previous response
table_contents = client.models.generate_content(
        model='gemini-2.5-pro',
        contents=[types.Part.from_bytes(
        data=filepath.read_bytes(),
        mime_type='application/pdf',
      ),
      prompt],
        config={
            'response_mime_type': 'application/json',
            'response_schema': list[Table],
        },
    )

table_contents

# %%
print("\nAs Markdown:")
print(table.to_markdown())

# %% [markdown]
# More examples with PDFs [here](https://ai.google.dev/gemini-api/docs/document-processing?lang=python).

# %% [markdown]
# # Check Gemini Docs for All Capabilities
#
# - [Audio Understanding](https://ai.google.dev/gemini-api/docs/audio)
# - [Video Understanding](https://ai.google.dev/gemini-api/docs/video-understanding)
